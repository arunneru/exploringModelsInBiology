# %%
1+1
# Out:
# 2

# %%
a = 2.0
# Out:
# 2.0

# %%
a = "Arun"
# Out:
# "Arun"

# %%
typeof(a)
# Out:
# Float64

# %%
a = [1.0,2.0,3.0,4.0]
# Out:
# 4-element Vector{Float64}:
#  1.0
#  2.0
#  3.0
#  4.0

# %%
a.^2
# Out:
# 4-element Vector{Float64}:
#   1.0
#   4.0
#   9.0
#  16.0

# %%
sort(a)
# Out:
# 4-element Vector{Float64}:
#  1.0
#  2.0
#  3.0
#  4.0

# %%
b = [3,4,2,1]
# Out:
# 4-element Vector{Int64}:
#  3
#  4
#  2
#  1

# %%
sort(b)
# Out:
# 4-element Vector{Int64}:
#  1
#  2
#  3
#  4

# %%
b
# Out:
# 4-element Vector{Int64}:
#  3
#  4
#  2
#  1

# %%
sort!(b)
# Out:
# 4-element Vector{Int64}:
#  1
#  2
#  3
#  4

# %%
b
# Out:
# 4-element Vector{Int64}:
#  1
#  2
#  3
#  4

# %%
mySin(x) = sin(x)
# Out:
# mySin (generic function with 1 method)

# %%
mySin.(b)
# Out:
# 4-element Vector{Float64}:
#   0.8414709848078965
#   0.9092974268256817
#   0.1411200080598672
#  -0.7568024953079282

# %%
#using Pkg; Pkg.install("CairoMakie")

# %%
using CairoMakie

# %%
fig = Figure(size=(500,500))
ax = fig[1,1]
# Out:
# GridPosition(GridLayout[1, 1] (0 children), GridLayoutBase.Span(1:1, 1:1), GridLayoutBase.Inner())

# %%
xvals = 1:10
# Out:
# 1:10

# %%
typeof(xvals)
# Out:
# UnitRange{Int64}

# %%
yvals = mySin.(xvals)
# Out:
# 10-element Vector{Float64}:
#   0.8414709848078965
#   0.9092974268256817
#   0.1411200080598672
#  -0.7568024953079282
#  -0.9589242746631385
#  -0.27941549819892586
#   0.6569865987187891
#   0.9893582466233818
#   0.4121184852417566
#  -0.5440211108893698

# %%
lines(xvals, yvals)

# %%
xvals=1:0.1:10
yvals=mySin.(xvals)
fig = Figure(size=(400,400))
ax = fig[1,1]
lines(xvals, yvals)

# %%
mySin(x,f) = sin(f*x)
# Out:
# mySin (generic function with 2 methods)

# %%
using LinearAlgebra

# %%
?Matrix
# Out:
# search: Matrix BitMatrix DenseMatrix rstrip tril triu Main istril lstrip strip
#   Matrix{T}(missing, m, n)
#
#   Construct a Matrix{T} of size m×n, initialized with missing entries. Element
#   type T must be able to hold these values, i.e. Missing <: T.
#
#   Examples
#   ≡≡≡≡≡≡≡≡
#
#   julia> Matrix{Union{Missing, String}}(missing, 2, 3)
#   2×3 Matrix{Union{Missing, String}}:
#    missing  missing  missing
#    missing  missing  missing
#
#   ────────────────────────────────────────────────────────────────────────────
#
#   Matrix{T}(nothing, m, n)
#
#   Construct a Matrix{T} of size m×n, initialized with nothing entries. Element
#   type T must be able to hold these values, i.e. Nothing <: T.
#
#   Examples
#   ≡≡≡≡≡≡≡≡
#
#   julia> Matrix{Union{Nothing, String}}(nothing, 2, 3)
#   2×3 Matrix{Union{Nothing, String}}:
#    nothing  nothing  nothing
#    nothing  nothing  nothing
#
#   ────────────────────────────────────────────────────────────────────────────
#
# ...

# %%
xvals=1:0.05:10
yvals=mySin.(xvals,4)
freq1 = 2
freq2 = 4

fig = Figure(size=(400,400))
ga = fig[1,1]




lines(xvals, yvals)
